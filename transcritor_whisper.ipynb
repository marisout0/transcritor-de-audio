# %% [markdown]
# # 🎙️ Transcritor e Tradutor com Whisper
# Execute as células abaixo na ordem.

# %%
# !pip install git+https://github.com/openai/whisper.git 
# !sudo apt update && sudo apt install ffmpeg

# %% [markdown]
# ### 📂 Upload e Processamento
# 1. Suba seu áudio na pasta lateral.
# 2. Altere o nome abaixo e rode.

# %%
# !whisper "seu_audio.mp3" --model medium --task translate

from google.colab import files
import glob
for f in glob.glob("seu_audio*"):
    files.download(f)
